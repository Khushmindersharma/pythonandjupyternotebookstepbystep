# %%
# Seaborn Library

# Seaborn is a library for making statistical graph in python.
# Matplotlib helps is 2D graphs.

# Seaborn is integrated with Matplotlib and pandas.

# Visualization is an important part of storytelling,we can gain a lot of information from data
# by simply just plotting the features of data.Python provides a numerous number of libraries
# for data visualization.

# Seaborn is library for making statistical graphics in Python.It built on top of Matplotlib
# and integrates closely with pandas data structures.

# Seaborn helps you explore and understand your data.Its plotting functions operate on 
# dataframes and arrays containing whole datasets and internally perform the nested semantic
# mapping and statistical aggregation to produce informative plots.Its oriented,declarative API
# lets you focus on what the different elements of your plot rather than on the details of how to draw them.

# Different categories of plot in Seaborn
# Plots are absically used for visualization the relationship between variables.
# Those variables can be either completely numerical or a category like a group,class or division.
# Seaborn divides the plot into the below categories.

# Regression plots:-The regression plots in seaborn are primarily intended to add a visual guide.
# that helps to emphasize patterns in the dataset during exploratory data analysis.

# Matriz plots:- A matrix plot is an array of scatterplots.

# Multi-plot grids:-It is a useful approach to draw multiple instances of the same visual of different
# subsets of the dataset.

# Relational plots : This plot is used to understand the relation between two variables.

# Categorical Plots:- This plot deals with categorical variables and how they can be visualized.

# Distribution Plots:- This plot is used for examining univariate and bivariate distributions.

# %%
# Installation of seaborn library
# for python environment

# pip install seaborn
# for conda environment
# conda install seaborn

# %%
# Dependencies for seaborn library.

# There are some libraries that must be installed before using seaborn.Here we will list out
# some basics that are a must for using Seaborn.

# Python 3.6 or higher.
# numpy >= 1.13.3
# scipy >= 1.0.1
# pandas >= 0.22.0
# matplotlib >= 2.1.2

# %%
# Question

# Which library is used for create statitical graphs.
# Seaborn.

# _______ plots are used to visually assess the uncertainty of the statistic.
# bootstrap plots.

# which of the following is not a type of plot available in seaborn?
# Tree plot.

# which function is use to create a histogram in seaborn.
# sns.histplot() function is used for histogram in seabron library

# %%
# !pip install seaborn

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
var1 = [1,2,3,4,5,6,7,8]
var2 = [8,7,6,5,4,3,2,1]

# matplotlib

plt.plot(var1,var2)
plt.show()

# %%
import seaborn as sn
import matplotlib.pyplot as plt

var1 = [1,2,3,4,5,6,7,8]
var2 = [8,7,6,5,4,3,2,1]

# seaborn

sn.lineplot(x = var1, y = var2)
plt.show()

# %%
import seaborn as sns
import pandas as pd

var = [1,2,3,4,5,6,7,8]
var1= [8,7,6,5,4,3,2,1]

df = pd.DataFrame({"var":var,"var1":var1})
sns.lineplot(x = 'var', y = 'var1', data = df)
plt.show()

# %%
df
# Out:
#    var  var1
# 0    1     8
# 1    2     7
# 2    3     6
# 3    4     5
# 4    5     4
# 5    6     3
# 6    7     2
# 7    8     1

# %%
# seaborn gives additional detailed in the graphs.

# %%
# seaborn dataset github [googling to get the datasets].

df1 = sns.load_dataset("penguins")

# %%
df1
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
# task seaborn lineplot graph.
import seaborn as sns
import pandas as pd

sns.lineplot(x = 'bill_length_mm', y = 'flipper_length_mm', data = df1 )
plt.show()

# %%
# categorical data visualization.

import seaborn as sns
import pandas as pd

sns.lineplot(x = 'bill_length_mm', y = 'flipper_length_mm', data = df1 , hue = 'sex')
plt.show()

# %%
# to get different colors.

import seaborn as sns
import pandas as pd

sns.lineplot(x = 'bill_length_mm', y = 'flipper_length_mm', data = df1 , hue = 'sex', style = 'sex',
             palette = 'rocket_r', markers = ["o",">"])
plt.show()

# %%
df1 = sns.load_dataset("penguins").head(20)

# %%
df1
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 3   Adelie  Torgersen             NaN            NaN                NaN
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 8   Adelie  Torgersen            34.1           18.1              193.0
# 9   Adelie  Torgersen            42.0           20.2              190.0
# 10  Adelie  Torgersen            37.8           17.1              186.0
# 11  Adelie  Torgersen            37.8           17.3              180.0
# ...

# %%
sns.lineplot(x = 'bill_length_mm', y = 'flipper_length_mm', data = df1 , hue = 'sex', style = 'sex',
             palette = 'rocket_r', markers = ["o",">"])
plt.show()

# %%
# to get the grid line in the graphs.

sns.lineplot(x = 'bill_length_mm', y = 'flipper_length_mm', data = df1 , hue = 'sex', style = 'sex',
             palette = 'rocket_r', markers = ["o",">"])
plt.grid()
plt.show()

# %%
# to use title use plt.title.

sns.lineplot(x = 'bill_length_mm', y = 'flipper_length_mm', data = df1 , hue = 'sex', style = 'sex',
             palette = 'rocket_r', markers = ["o",">"])

plt.grid()
plt.title("This is a line graph related to penguins")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
data1 = sns.load_dataset("penguins")

# %%
data1
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
data1["island"]
# Out:
# 0      Torgersen
# 1      Torgersen
# 2      Torgersen
# 3      Torgersen
# 4      Torgersen
#          ...
# 339       Biscoe
# 340       Biscoe
# 341       Biscoe
# 342       Biscoe
# 343       Biscoe
# Name: island, Length: 344, dtype: object

# %%
sns.barplot(x = data1.island,y = data1.bill_length_mm)
plt.show()

# %%
sns.barplot(x = "island",y = "bill_length_mm", data = data1)

plt.show()

# %%
# using hue

sns.barplot(x = "island",y = "bill_length_mm", data = data1, hue = "sex")

plt.show()

# %%
# order set in x = axis. order parameter.

order1 = ["Dream","Torgersen","Biscoe"]

sns.barplot( x = 'island', y = 'bill_length_mm', data = data1,hue = 'sex', order = order1)
plt.show()

# %%
# change the order of the bars.hue_order.

order1 = ["Dream","Torgersen","Biscoe"]

sns.barplot( x = 'island', y = 'bill_length_mm', data = data1,hue = 'sex', 
            order = order1, hue_order = ['Female','Male'])
plt.show()

# %%
# seting the colors and order both.

order1 = ['Dream','Torgersen','Biscoe']

sns.barplot(x = 'island',y = 'bill_length_mm', data = data1)
plt.show()

# %%
order1 = ['Dream','Torgersen','Biscoe']

sns.barplot(x = 'island',y = 'bill_length_mm', data = data1, color = 'green')
plt.show()

# %%
order1 = ['Dream','Torgersen','Biscoe']

sns.barplot(x = 'island', y = 'bill_length_mm' , data = data1, hue ='sex', palette = 'Accent')
plt.show()

# %%
order1 = ['Dream','Torgersen','Biscoe']

sns.barplot(x = 'island', y = 'bill_length_mm' , data = data1, hue ='sex', palette = 'prism')
plt.show()

# %%
order1 = ['Dream','Torgersen','Biscoe']

sns.barplot(x = 'island', y = 'bill_length_mm' , data = data1, hue ='sex', palette = 'gist_earth')
plt.show()

# %%
# Saturation parameter.

sns.barplot(x ='island',y = 'bill_length_mm', data = data1,hue = 'sex',
            palette = 'gist_earth', saturation = .7)
plt.show()

# %%
# make of histogram in seaborn

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

data1
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.displot(data1['flipper_length_mm'])
plt.show()

# %%
# bins parameter.

sns.displot( data1['flipper_length_mm'],bins = [170,180,190,200,210,220,230,240])
plt.show()

# %%
# changing the color.

sns.displot(data1['flipper_length_mm'],bins = [170,180,190,200,210,220,230,240], color = 'g')
plt.show()

# %%
sns.displot(data1['flipper_length_mm'],bins = [170,180,190,200,210,220,230,240], color = 'red')
plt.show()

# %%
# kde = Kernel Densecity in histogram.

sns.displot(data1['flipper_length_mm'],bins = [170,180,190,200,210,220,230,240], kde = True, color = 'red')
plt.show()

# %%
sns.displot(data1['flipper_length_mm'],bins = [170,180,190,200,210,220,230,240],kde = False , color = 'green')
plt.show()
